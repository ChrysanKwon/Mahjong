# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# copy over the dataset into the root directory of the Colab VM

# !cp /content/drive/MyDrive/mahjongData.zip /content

# %%
# !unzip /content/mahjongData.zip -d /content/
# Out:
# Archive:  /content/mahjongData.zip
# replace /content/mahjongData/images/train/10.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !ls /content/mahjongData/images/train

# %%
# https://docs.ultralytics.com/usage/cli/
# https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb

# data: yaml file to define path to data, classes' names
# model: yolov5x.pt yolov5l.pt yolov5m.pt yolov5s.pt yolov5n.pt
# a full list of train arguments: https://docs.ultralytics.com/usage/cfg/

# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolo/mahjong.yaml epochs=300 imgsz=640 plots=True fliplr=0 batch=8 shear=0.1 perspective=0.0001 degrees=5

# %%
# !cp '/content/runs/detect/train/weights/best.pt' /content/drive/MyDrive/yolo/

# %%
source=['/content/drive/MyDrive/yolo/test1.png', '/content/drive/MyDrive/yolo/test2.png', '/content/drive/MyDrive/yolo/test3.png', '/content/drive/MyDrive/yolo/test4.png', '/content/drive/MyDrive/yolo/test5.png', '/content/drive/MyDrive/yolo/test6.png', '/content/drive/MyDrive/yolo/test7.png', '/content/drive/MyDrive/yolo/test8.png', '/content/drive/MyDrive/yolo/test9.png', '/content/drive/MyDrive/yolo/test10.png']

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo/best.pt source='/content/drive/MyDrive/yolo' conf=0.25  save=True
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11138742 parameters, 0 gradients
#
# image 1/10 /content/drive/MyDrive/yolo/test.png: 64x640 1 2p, 1 6p, 1 8p, 1 3s, 1 1m, 1 3m, 1 5m, 1 6m, 1 7m, 1 6z, 1 1z, 1 3z, 1 2z, 88.6ms
# image 2/10 /content/drive/MyDrive/yolo/test10.png: 480x640 1 3p, 1 5p, 1 6p, 2 7ps, 2 3ss, 1 4s, 1 5s, 1 7s, 2 5ms, 1 7m, 1 2z, 94.4ms
# image 3/10 /content/drive/MyDrive/yolo/test2.png: 384x640 1 1p, 1 3p, 1 9p, 1 5m, 1 1z, 1 3z, 1 2z, 101.7ms
# image 4/10 /content/drive/MyDrive/yolo/test3.png: 96x640 2 1ms, 1 2m, 1 3m, 1 4m, 1 5m, 4 6ms, 1 8m, 1 5z, 1 6z, 1 4z, 124.3ms
# image 5/10 /content/drive/MyDrive/yolo/test4.png: 64x640 1 1p, 2 2ps, 1 6p, 1 8p, 2 9ps, 1 1z, 1 3z, 2 4zs, 9.8ms
# image 6/10 /content/drive/MyDrive/yolo/test5.png: 96x640 1 2p, 1 6p, 1 8p, 2 3ss, 1 4s, 1 5s, 1 5z, 1 7z, 1 4z, 10.0ms
# ...

# %%
display(Image(filename='/content/runs/detect/predict/test.jpg', width=600))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5853db123365> in <cell line: 1>()
# ----> 1 display(Image(filename='/content/runs/detect/predict6/test6.jpg', width=600))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
model = YOLO('/content/runs/detect/train4/weights/best.pt')
results = model.predict(source='/content/drive/MyDrive/yolo/test.png', conf=0.25)
hand=results[0].boxes.cls.detach().cpu().numpy()
